# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Run this from the _talks/ directory, which contains .md files of all your talks. This scrapes the location YAML field from each .md file, geolocates it with geopy/Nominatim, and uses the getorg library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# %pip install getorg --upgrade
import glob
import getorg
from geopy import Nominatim
# Out:
# Requirement already satisfied: getorg in .\.venv\Lib\site-packages (0.3.1)
# Requirement already satisfied: geopy in .\.venv\Lib\site-packages (from getorg) (2.4.1)
# Requirement already satisfied: pygithub in .\.venv\Lib\site-packages (from getorg) (2.9.0)
# Requirement already satisfied: retrying in .\.venv\Lib\site-packages (from getorg) (1.4.2)
# Requirement already satisfied: geographiclib<3,>=1.52 in .\.venv\Lib\site-packages (from geopy->getorg) (2.1)
# Requirement already satisfied: pynacl>=1.4.0 in .\.venv\Lib\site-packages (from pygithub->getorg) (1.6.2)
# Requirement already satisfied: requests>=2.14.0 in .\.venv\Lib\site-packages (from pygithub->getorg) (2.33.0)
# Requirement already satisfied: pyjwt>=2.4.0 in .\.venv\Lib\site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.12.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in .\.venv\Lib\site-packages (from pygithub->getorg) (4.15.0)
# Requirement already satisfied: urllib3>=1.26.0 in .\.venv\Lib\site-packages (from pygithub->getorg) (2.6.3)
# Requirement already satisfied: cryptography>=3.4.0 in .\.venv\Lib\site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (46.0.6)
# Requirement already satisfied: cffi>=2.0.0 in .\.venv\Lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.0.0)
# Requirement already satisfied: pycparser in .\.venv\Lib\site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.4.0->pygithub->getorg) (3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\Lib\site-packages (from requests>=2.14.0->pygithub->getorg) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in .\.venv\Lib\site-packages (from requests>=2.14.0->pygithub->getorg) (3.11)
# Requirement already satisfied: certifi>=2023.5.7 in .\.venv\Lib\site-packages (from requests>=2.14.0->pygithub->getorg) (2026.2.25)
# Note: you may need to restart the kernel to use updated packages.

# %%
g = glob.glob("*.md")

# %%
geocoder = Nominatim(user_agent="mazor-talk-map")
location_dict = {}
location = ""
permalink = ""
title = ""

# %%
for file in g:
    with open(file, 'r') as f:
        lines = f.read()
        if lines.find('location: "') > 1:
            loc_start = lines.find('location: "') + 11
            lines_trim = lines[loc_start:]
            loc_end = lines_trim.find('"')
            location = lines_trim[:loc_end]
                            
           
        location_dict[location] = geocoder.geocode(location)
        print(location, "\n", location_dict[location])
# Out:
#
#  None
#
#  None
#
#  None

# %%
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="../talkmap", hashed_usernames=False)
# Out:
# 'Written map to ../talkmap/'
